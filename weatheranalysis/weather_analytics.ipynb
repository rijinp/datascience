# %%
import pandas as pd

# %%
df  = pd.read_csv('Weather Data.csv')

# %%
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
df['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %%
df[(df['Weather']=='Clear') & (df['Wind Speed_km/h']==4)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 433     1/19/2012 1:00   -15.2             -18.4         76                4
# 499    1/21/2012 19:00   -13.4             -19.9         58                4
# 500    1/21/2012 20:00   -18.5             -24.4         60                4
# 505     1/22/2012 1:00   -17.5             -21.3         72                4
# 601     1/26/2012 1:00    -7.0             -12.1         67                4
# ...                ...     ...               ...        ...              ...
# 8638  12/25/2012 22:00   -10.9             -13.2         83                4
# 8640   12/26/2012 0:00   -11.8             -13.5         87                4
# 8642   12/26/2012 2:00   -12.7             -14.4         87                4
# 8645   12/26/2012 5:00   -12.7             -14.1         89                4
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
a = df[df['Wind Speed_km/h']==4]

# %%
a.head(4)
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0    1/1/2012 0:00    -1.8              -3.9         86                4
# 1    1/1/2012 1:00    -1.8              -3.7         87                4
# 96   1/5/2012 0:00    -8.8             -11.7         79                4
# 101  1/5/2012 5:00    -7.0              -9.5         82                4
#
#      Visibility_km  Press_kPa Weathers
# 0              8.0     101.24      Fog
# 1              8.0     101.24      Fog
# 96             9.7     100.32     Snow
# 101            4.0     100.19     Snow

# %%
df.rename(columns={'Weather':'Weathers'},inplace=True)

# %% [markdown]
# # mean visibility

# %%
df['Visibility_km'].mean()
# Out:
# 27.664446721311478

# %%
#find standerd deviation in pandas
df.std()
# Out:
# Temp_C              11.687883
# Dew Point Temp_C    10.883072
# Rel Hum_%           16.918881
# Wind Speed_km/h      8.688696
# Visibility_km       12.622688
# Press_kPa            0.844005
# dtype: float64

# %%
df.corr()
# Out:
#                     Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Temp_C            1.000000          0.932714  -0.220182        -0.061876
# Dew Point Temp_C  0.932714          1.000000   0.139494        -0.095685
# Rel Hum_%        -0.220182          0.139494   1.000000        -0.092743
# Wind Speed_km/h  -0.061876         -0.095685  -0.092743         1.000000
# Visibility_km     0.273455          0.050813  -0.633683         0.004883
# Press_kPa        -0.236389         -0.320616  -0.231424        -0.356613
#
#                   Visibility_km  Press_kPa
# Temp_C                 0.273455  -0.236389
# Dew Point Temp_C       0.050813  -0.320616
# Rel Hum_%             -0.633683  -0.231424
# Wind Speed_km/h        0.004883  -0.356613
# Visibility_km          1.000000   0.231847
# Press_kPa              0.231847   1.000000

# %%
df['Weathers'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
df.groupby('Weathers').mean()
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weathers
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %%
import matplotlib.pyplot as plt

# %%
df.plot(kind  = 'hist',x='Wind Speed_km/h',y = 'Dew Point Temp_C' )
plt.show()

# %%
df.groupby('Weathers').min()
# Out:
#                                                 Date/Time  Temp_C  \
# Weathers
# Clear                                      1/11/2012 1:00   -23.3
# Cloudy                                     1/1/2012 17:00   -21.4
# Drizzle                                   1/23/2012 21:00     1.1
# Drizzle,Fog                               1/23/2012 20:00     0.0
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/17/2012 15:00     0.9
# Drizzle,Snow,Fog                         12/18/2012 21:00     0.3
# Fog                                         1/1/2012 0:00   -16.0
# Freezing Drizzle                          1/13/2012 10:00    -9.0
# Freezing Drizzle,Fog                        1/1/2012 2:00    -6.4
# Freezing Drizzle,Haze                      2/1/2012 11:00    -5.8
# Freezing Drizzle,Snow                      1/13/2012 3:00    -8.3
# Freezing Fog                               1/22/2012 6:00   -19.0
# ...

# %%
# plot graph between wether and the visibility
import matplotlib.pyplot as plt
time = [i for i ,df in df.groupby(['Weathers'])]
plt.bar(time,df.groupby(['Weathers']).sum()['Visibility_km'])
plt.xticks(time,rotation='vertical', size=8)
plt.ylabel('Visibility_km')
plt.xlabel('Weathers')
plt.show()
